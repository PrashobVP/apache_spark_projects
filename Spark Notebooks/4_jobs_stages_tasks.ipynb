# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.read.format("csv")\
        .option("header",True)\
        .load("/Volumes/sparkcatalog/raw/source/raw_orders/orders.csv")

# %%
# Wide Transformation
df = df.repartition(2)

# Narrow Transformation - 1
df = df.select("order_id","customer_id")

# Narrow Transformation - 2
df = df.filter(col("order_id")==1001)

# Wide Transformation
df = df.groupBy("customer_id").count()

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>count</th></tr></thead><tbody><tr><td>C164</td><td>1</td></tr></tbody></table></div>
